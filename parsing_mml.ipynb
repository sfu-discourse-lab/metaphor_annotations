# %%
import rdflib
from rdflib import Graph

g = Graph()

# %%
import os

# %%
print(os.listdir())#'mr-en_es_fr-extract-20241104160157'))
# Out:
# ['.git', '.ipynb_checkpoints', '.Rhistory', 'anno_sample.ipynb', 'appraisal_metaphor_comparison.ipynb', 'appraisal_metaphor_comparison_v2.ipynb', 'appraisal_v_metaphor.ipynb', 'appraisal_v_metaphor_v2.ipynb', 'compare_annotations.ipynb', 'data_analysis.ipynb', 'engl_mml.rdf.rdf', 'filenames-romina-laptop.csv', 'filenames.csv', 'jan18.csv', 'jan21.csv', 'lab docs', 'mar4.csv', 'metaphor_anno.json', 'metaphor_labels_mar26_2025.json', 'mr-en_es_fr-extract-20241104160157', 'mr_en.owl', 'page_break_fix.ipynb', 'parsing_mml.ipynb', 'project-2-at-2025-05-20-edit.json', 'project-2-at-2025-05-20.json', 'project-2-at-2025.csv', 'SOCC', 'tokenized_comments.csv', 'tokenizing.ipynb', 'what.ipynb']

# %%
g.parse("mr-en_es_fr-extract-20241104160157/mr-en-20241104160157.rdf")
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\xml\sax\expatreader.py:217, in ExpatParser.feed(self, data, isFinal)
#     212 try:
#     213     # The isFinal parameter is internal to the expat reader.
#     214     # If it is set to true, expat will check validity of the entire
#     215     # document. When feeding chunks, they are not normally final -
#     216     # except when invoked from close.
# --> 217     self._parser.Parse(data, isFinal)
#     218 except expat.error as e:
#
# ExpatError: syntax error: line 2, column 0
#
# During handling of the above exception, another exception occurred:
#
# SAXParseException                         Traceback (most recent call last)
# Cell In[4], line 1
# ...

# %%
print(len(g))

# %%
# prints: 2

import pprint
for stmt in g:
    pprint.pprint(stmt)
# Out:
# (rdflib.term.URIRef('https://metaphor.icsi.berkeley.edu/en/MetaphorRepository.owl#LexicalUnit_1298'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('https://metaphor.icsi.berkeley.edu/en/MetaphorRepository.owl#Binding_241'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('https://metaphor.icsi.berkeley.edu/metaphor/MetaphorOntology.owl#Binding'))
# (rdflib.term.URIRef('https://metaphor.icsi.berkeley.edu/en/MetaphorRepository.owl#Mapping_288'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('https://metaphor.icsi.berkeley.edu/en/MetaphorRepository.owl#LexicalUnit_385'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
# ...

# %%
pip install rdflib
# Out:
# ...
#    ---------------------------------------- 0.0/565.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/565.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/565.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/565.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/565.1 kB ? eta -:--:--
#    -------------------------------------- 565.1/565.1 kB 625.8 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\romha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import rdflib
g = rdflib.Graph()
g.parse ('mr_en.owl', format='application/rdf+xml')#format='xml')

len(g)
# mr_en = rdflib.Namespace('http://purl.org/mr_en/ontology/mr_en.owl')
# g.bind('mr_en', mr_en)
# query = """
# select distinct ?p 
# where { ?s ?p ?o}
#         LIMIT 5
#         """
# result = g.query(query)
# print(result.serialize(format='csv'))
# Out:
# 83199
